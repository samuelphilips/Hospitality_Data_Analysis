# %% [markdown]
# <a href="https://colab.research.google.com/github/samuelphilips/Hospitality_Data_Analysis/blob/main/Hotel_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Hospitality Domain Data Analysis**

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# **DATA EXPLORATION**

# %%
#reading Fact_bookings

Fact_bookings=pd.read_csv("/content/fact_bookings.csv")
Fact_bookings.head(10)
# Out:
#           booking_id  property_id booking_date check_in_date checkout_date  \
# 0   May012216558RT11        16558     27-04-22      1/5/2022      2/5/2022
# 1   May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 2   May012216558RT13        16558     28-04-22      1/5/2022      4/5/2022
# 3   May012216558RT14        16558     28-04-22      1/5/2022      2/5/2022
# 4   May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
# 5   May012216558RT16        16558     1/5/2022      1/5/2022      3/5/2022
# 6   May012216558RT17        16558     28-04-22      1/5/2022      6/5/2022
# 7   May012216558RT18        16558     26-04-22      1/5/2022      3/5/2022
# 8   May012216558RT19        16558     30-04-22      1/5/2022      2/5/2022
# 9  May012216558RT110        16558     28-04-22      1/5/2022      2/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# ...

# %%
# shape and size of Fact_bookings
print("shape of Fact_bookings is ",Fact_bookings.shape)
print("shize of Fact_bookings is ",Fact_bookings.size)
# Out:
# shape of Fact_bookings is  (134590, 12)
# shize of Fact_bookings is  1615080

# %%
#unique room categories
Fact_bookings["room_category"].unique()
# Out:
# array(['RT1', 'RT2', 'RT3', 'RT4'], dtype=object)

# %%
# unique booking platforms
Fact_bookings["booking_platform"].unique()
# Out:
# array(['direct online', 'others', 'logtrip', 'tripster', 'makeyourtrip',
#        'journey', 'direct offline'], dtype=object)

# %%
#count of bookings per platform
Fact_bookings["booking_platform"].value_counts()
# Out:
# others            55066
# makeyourtrip      26898
# logtrip           14756
# direct online     13379
# tripster           9630
# journey            8106
# direct offline     6755
# Name: booking_platform, dtype: int64

# %%
# ploting the bookings per platform

Fact_bookings["booking_platform"].value_counts().plot(kind="bar")
# Out:
# <Axes: >

# %%
min_revenue_generated=Fact_bookings["revenue_generated"].min()
print("min of revenue_generated",min_revenue_generated)
max_revenue_generated=Fact_bookings["revenue_generated"].max()
print("max of revenue_generated",max_revenue_generated)
# Out:
# min of revenue_generated 6500
# max of revenue_generated 28560000

# %%
dim_date=pd.read_csv("/content/dim_date.csv")
dim_hotels=pd.read_csv("/content/dim_hotels.csv")
dim_rooms=pd.read_csv("/content/dim_rooms.csv")
New_data=pd.read_csv("/content/new_data_august.csv")

# %%
dim_hotels["category"].value_counts()
# Out:
# Luxury      16
# Business     9
# Name: category, dtype: int64

# %%
dim_hotels["city"].value_counts().sort_values()
# Out:
# Delhi        5
# Hyderabad    6
# Bangalore    6
# Mumbai       8
# Name: city, dtype: int64

# %%
Facts_aggregated_bookings=pd.read_csv("/content/fact_aggregated_bookings.csv")
Facts_aggregated_bookings.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
# 4        16558      1-May-22           RT1                   18      19.0

# %%
Facts_aggregated_bookings["property_id"].unique()
# Out:
# array([16559, 19562, 19563, 17558, 16558, 17560, 19558, 19560, 17561,
#        16560, 16561, 16562, 16563, 17559, 17562, 17563, 18558, 18559,
#        18561, 18562, 18563, 19559, 19561, 17564, 18560])

# %%
Facts_aggregated_bookings["property_id"].nunique()
# Out:
# 25

# %%
Facts_aggregated_bookings.groupby("property_id")["successful_bookings"].sum()
# Out:
# property_id
# 16558    3153
# 16559    7338
# 16560    4693
# 16561    4418
# 16562    4820
# 16563    7211
# 17558    5053
# 17559    6142
# 17560    6013
# 17561    5183
# 17562    3424
# 17563    6337
# 17564    3982
# 18558    4475
# 18559    5256
# 18560    6638
# 18561    6458
# 18562    7333
# 18563    4737
# 19558    4400
# 19559    4729
# 19560    6079
# 19561    5736
# 19562    5812
# 19563    5413
# Name: successful_bookings, dtype: int64

# %%
Facts_aggregated_bookings["capacity"].max()
# Out:
# 50.0

# %%
Facts_aggregated_bookings[Facts_aggregated_bookings.successful_bookings>Facts_aggregated_bookings.capacity]
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity
# 3           17558      1-May-22           RT1                   30      19.0
# 12          16563      1-May-22           RT1                  100      41.0
# 4136        19558     11-Jun-22           RT2                   50      39.0
# 6209        19560      2-Jul-22           RT1                  123      26.0
# 8522        19559     25-Jul-22           RT1                   35      24.0
# 9194        18563     31-Jul-22           RT4                   20      18.0

# %%
Facts_aggregated_bookings[Facts_aggregated_bookings.capacity==Facts_aggregated_bookings.capacity.max()]
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity
# 27          17558      1-May-22           RT2                   38      50.0
# 128         17558      2-May-22           RT2                   27      50.0
# 229         17558      3-May-22           RT2                   26      50.0
# 328         17558      4-May-22           RT2                   27      50.0
# 428         17558      5-May-22           RT2                   29      50.0
# ...           ...           ...           ...                  ...       ...
# 8728        17558     27-Jul-22           RT2                   22      50.0
# 8828        17558     28-Jul-22           RT2                   21      50.0
# 8928        17558     29-Jul-22           RT2                   23      50.0
# 9028        17558     30-Jul-22           RT2                   32      50.0
# 9128        17558     31-Jul-22           RT2                   30      50.0
#
# [92 rows x 5 columns]

# %% [markdown]
# **CLEANING**

# %%
Fact_bookings.shape
# Out:
# (134590, 12)

# %%
Fact_bookings.describe()
# Out:
#          property_id      no_guests  ratings_given  revenue_generated  \
# count  134590.000000  134587.000000   56683.000000       1.345900e+05
# mean    18061.113493       2.036170       3.619004       1.537805e+04
# std      1093.055847       1.034885       1.235009       9.303604e+04
# min     16558.000000     -17.000000       1.000000       6.500000e+03
# 25%     17558.000000       1.000000       3.000000       9.900000e+03
# 50%     17564.000000       2.000000       4.000000       1.350000e+04
# 75%     18563.000000       2.000000       5.000000       1.800000e+04
# max     19563.000000       6.000000       5.000000       2.856000e+07
#
#        revenue_realized
# count     134590.000000
# mean       12696.123256
# std         6928.108124
# min         2600.000000
# 25%         7600.000000
# 50%        11700.000000
# 75%        15300.000000
# max        45220.000000

# %%
Fact_bookings[Fact_bookings["no_guests"]<=0]
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 0        May012216558RT11        16558     27-04-22      1/5/2022
# 3        May012216558RT14        16558     28-04-22      1/5/2022
# 17924    May122218559RT44        18559    12/5/2022     12/5/2022
# 18020    May122218561RT22        18561     8/5/2022     12/5/2022
# 18119   May122218562RT311        18562     5/5/2022     12/5/2022
# 18121   May122218562RT313        18562    10/5/2022     12/5/2022
# 56715    Jun082218562RT12        18562     5/6/2022      8/6/2022
# 119765  Jul202219560RT220        19560     19-07-22      20-07-22
# 134586   Jul312217564RT47        17564     30-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 0           2/5/2022       -3.0           RT1    direct online            1.0
# 3           2/5/2022       -2.0           RT1           others            NaN
# ...

# %%
# removing the neagative guests records

Fact_bookings=Fact_bookings[Fact_bookings["no_guests"]>0]
Fact_bookings
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 1        May012216558RT12        16558     30-04-22      1/5/2022
# 2        May012216558RT13        16558     28-04-22      1/5/2022
# 4        May012216558RT15        16558     27-04-22      1/5/2022
# 5        May012216558RT16        16558     1/5/2022      1/5/2022
# 6        May012216558RT17        16558     28-04-22      1/5/2022
# ...                   ...          ...          ...           ...
# 134584   Jul312217564RT45        17564     30-07-22      31-07-22
# 134585   Jul312217564RT46        17564     29-07-22      31-07-22
# 134587   Jul312217564RT48        17564     30-07-22      31-07-22
# 134588   Jul312217564RT49        17564     29-07-22      31-07-22
# 134589  Jul312217564RT410        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 1           2/5/2022        2.0           RT1           others            NaN
# ...

# %%
Fact_bookings["revenue_generated"].min(),Fact_bookings["revenue_generated"].max()
# Out:
# (6500, 28560000)

# %%
mean,std=Fact_bookings["revenue_generated"].mean(),Fact_bookings["revenue_generated"].std()

# %%
higher_limit=mean+3*std
higher_limit
# Out:
# 294498.50173207896

# %%
lower_limit=mean-3*std
lower_limit
# Out:
# -263742.4278567056

# %%
#Outliers
Fact_bookings[Fact_bookings["revenue_generated"]>higher_limit]
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 2        May012216558RT13        16558     28-04-22      1/5/2022
# 111      May012216559RT32        16559     29-04-22      1/5/2022
# 315      May012216562RT22        16562     28-04-22      1/5/2022
# 562     May012217559RT118        17559     26-04-22      1/5/2022
# 129176   Jul282216562RT26        16562     21-07-22      28-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 2           4/5/2022        2.0           RT1          logtrip            5.0
# 111         2/5/2022        6.0           RT3    direct online            NaN
# 315         4/5/2022        2.0           RT2   direct offline            3.0
# 562         2/5/2022        2.0           RT1           others            NaN
# 129176      29-07-22        2.0           RT2    direct online            3.0
#
#        booking_status  revenue_generated  revenue_realized
# ...

# %%
# removing outliers
Fact_bookings=Fact_bookings[Fact_bookings["revenue_generated"]<higher_limit]
Fact_bookings
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 1        May012216558RT12        16558     30-04-22      1/5/2022
# 4        May012216558RT15        16558     27-04-22      1/5/2022
# 5        May012216558RT16        16558     1/5/2022      1/5/2022
# 6        May012216558RT17        16558     28-04-22      1/5/2022
# 7        May012216558RT18        16558     26-04-22      1/5/2022
# ...                   ...          ...          ...           ...
# 134584   Jul312217564RT45        17564     30-07-22      31-07-22
# 134585   Jul312217564RT46        17564     29-07-22      31-07-22
# 134587   Jul312217564RT48        17564     30-07-22      31-07-22
# 134588   Jul312217564RT49        17564     29-07-22      31-07-22
# 134589  Jul312217564RT410        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 1           2/5/2022        2.0           RT1           others            NaN
# ...

# %%
dim_rooms
# Out:
#   room_id    room_class
# 0     RT1      Standard
# 1     RT2         Elite
# 2     RT3       Premium
# 3     RT4  Presidential

# %%
Fact_bookings[Fact_bookings["room_category"]=="RT4"]["revenue_realized"].describe()
# Out:
# count    16071.000000
# mean     23439.308444
# std       9048.599076
# min       7600.000000
# 25%      19000.000000
# 50%      26600.000000
# 75%      32300.000000
# max      45220.000000
# Name: revenue_realized, dtype: float64

# %%
Fact_bookings.isnull().sum()
# Out:
# booking_id               0
# property_id              0
# booking_date             0
# check_in_date            0
# checkout_date            0
# no_guests                0
# room_category            0
# booking_platform         0
# ratings_given        77897
# booking_status           0
# revenue_generated        0
# revenue_realized         0
# dtype: int64

# %%
Facts_aggregated_bookings=pd.read_csv("/content/fact_aggregated_bookings.csv")

Facts_aggregated_bookings.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
# 4        16558      1-May-22           RT1                   18      19.0

# %%
Facts_aggregated_bookings.isnull().sum()
# Out:
# property_id            0
# check_in_date          0
# room_category          0
# successful_bookings    0
# capacity               2
# dtype: int64

# %%
Facts_aggregated_bookings["capacity"].median()
# Out:
# 25.0

# %%
Facts_aggregated_bookings["capacity"].fillna(Facts_aggregated_bookings["capacity"].median())
# Out:
# 0       30.0
# 1       30.0
# 2       30.0
# 3       19.0
# 4       19.0
#         ...
# 9195    18.0
# 9196    18.0
# 9197     6.0
# 9198     6.0
# 9199     4.0
# Name: capacity, Length: 9200, dtype: float64

# %%
Facts_aggregated_bookings[Facts_aggregated_bookings["successful_bookings"]>Facts_aggregated_bookings["capacity"]]
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity
# 3           17558      1-May-22           RT1                   30      19.0
# 12          16563      1-May-22           RT1                  100      41.0
# 4136        19558     11-Jun-22           RT2                   50      39.0
# 6209        19560      2-Jul-22           RT1                  123      26.0
# 8522        19559     25-Jul-22           RT1                   35      24.0
# 9194        18563     31-Jul-22           RT4                   20      18.0

# %% [markdown]
# **DATA TRANSFORMATION**

# %%
# adding occupancy_percentage to Facts_aggregated_bookings
Facts_aggregated_bookings["occupancy_percentage"]=Facts_aggregated_bookings["successful_bookings"]/Facts_aggregated_bookings["capacity"]
Facts_aggregated_bookings
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 0           16559      1-May-22           RT1                   25      30.0
# 1           19562      1-May-22           RT1                   28      30.0
# 2           19563      1-May-22           RT1                   23      30.0
# 3           17558      1-May-22           RT1                   30      19.0
# 4           16558      1-May-22           RT1                   18      19.0
# ...           ...           ...           ...                  ...       ...
# 9195        16563     31-Jul-22           RT4                   13      18.0
# 9196        16559     31-Jul-22           RT4                   13      18.0
# 9197        17558     31-Jul-22           RT4                    3       6.0
# 9198        19563     31-Jul-22           RT4                    3       6.0
# 9199        17561     31-Jul-22           RT4                    3       4.0
#
#       occupancy_percentage
# ...

# %%
Facts_aggregated_bookings["occupancy_percentage"]=Facts_aggregated_bookings["occupancy_percentage"].apply(lambda x: x*100,2)
Facts_aggregated_bookings.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
# 4        16558      1-May-22           RT1                   18      19.0
#
#    occupancy_percentage
# 0             83.333333
# 1             93.333333
# 2             76.666667
# 3            157.894737
# 4             94.736842

# %% [markdown]
# **Insights Generation**

# %%
Facts_aggregated_bookings
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 0           16559      1-May-22           RT1                   25      30.0
# 1           19562      1-May-22           RT1                   28      30.0
# 2           19563      1-May-22           RT1                   23      30.0
# 3           17558      1-May-22           RT1                   30      19.0
# 4           16558      1-May-22           RT1                   18      19.0
# ...           ...           ...           ...                  ...       ...
# 9195        16563     31-Jul-22           RT4                   13      18.0
# 9196        16559     31-Jul-22           RT4                   13      18.0
# 9197        17558     31-Jul-22           RT4                    3       6.0
# 9198        19563     31-Jul-22           RT4                    3       6.0
# 9199        17561     31-Jul-22           RT4                    3       4.0
#
#       occupancy_percentage
# ...

# %%
Facts_aggregated_bookings.groupby("room_category")["occupancy_percentage"].mean().round(2)
# Out:
# room_category
# RT1    58.22
# RT2    58.04
# RT3    58.03
# RT4    59.30
# Name: occupancy_percentage, dtype: float64

# %%
dim_rooms=pd.read_csv("/content/dim_rooms.csv")
dim_rooms.head()
# Out:
#   room_id    room_class
# 0     RT1      Standard
# 1     RT2         Elite
# 2     RT3       Premium
# 3     RT4  Presidential

# %%
Facts_aggregated_bookings
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 0           16559      1-May-22           RT1                   25      30.0
# 1           19562      1-May-22           RT1                   28      30.0
# 2           19563      1-May-22           RT1                   23      30.0
# 3           17558      1-May-22           RT1                   30      19.0
# 4           16558      1-May-22           RT1                   18      19.0
# ...           ...           ...           ...                  ...       ...
# 9195        16563     31-Jul-22           RT4                   13      18.0
# 9196        16559     31-Jul-22           RT4                   13      18.0
# 9197        17558     31-Jul-22           RT4                    3       6.0
# 9198        19563     31-Jul-22           RT4                    3       6.0
# 9199        17561     31-Jul-22           RT4                    3       4.0
#
#       occupancy_percentage
# ...

# %%
Facts_aggregated_bookings=pd.merge(Facts_aggregated_bookings,dim_rooms,left_on="room_category",right_on="room_id")
Facts_aggregated_bookings
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 0           16559      1-May-22           RT1                   25      30.0
# 1           19562      1-May-22           RT1                   28      30.0
# 2           19563      1-May-22           RT1                   23      30.0
# 3           17558      1-May-22           RT1                   30      19.0
# 4           16558      1-May-22           RT1                   18      19.0
# ...           ...           ...           ...                  ...       ...
# 9195        16563     31-Jul-22           RT4                   13      18.0
# 9196        16559     31-Jul-22           RT4                   13      18.0
# 9197        17558     31-Jul-22           RT4                    3       6.0
# 9198        19563     31-Jul-22           RT4                    3       6.0
# 9199        17561     31-Jul-22           RT4                    3       4.0
#
# ...

# %%
Facts_aggregated_bookings.drop("room_id",axis=1,inplace=True)

# %%
Facts_aggregated_bookings
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 0           16559      1-May-22           RT1                   25      30.0
# 1           19562      1-May-22           RT1                   28      30.0
# 2           19563      1-May-22           RT1                   23      30.0
# 3           17558      1-May-22           RT1                   30      19.0
# 4           16558      1-May-22           RT1                   18      19.0
# ...           ...           ...           ...                  ...       ...
# 9195        16563     31-Jul-22           RT4                   13      18.0
# 9196        16559     31-Jul-22           RT4                   13      18.0
# 9197        17558     31-Jul-22           RT4                    3       6.0
# 9198        19563     31-Jul-22           RT4                    3       6.0
# 9199        17561     31-Jul-22           RT4                    3       4.0
#
#       occupancy_percentage    room_class
# ...

# %%
Facts_aggregated_bookings.groupby("room_class")["occupancy_percentage"].mean().round(2)
# Out:
# room_class
# Elite           58.04
# Premium         58.03
# Presidential    59.30
# Standard        58.22
# Name: occupancy_percentage, dtype: float64

# %%
dim_hotels=pd.read_csv("/content/dim_hotels.csv")
dim_hotels.head()
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi
# 3        16561      Atliq Blu    Luxury   Delhi
# 4        16562      Atliq Bay    Luxury   Delhi

# %%
Facts_aggregated_bookings=pd.merge(Facts_aggregated_bookings,dim_hotels,on="property_id")
Facts_aggregated_bookings
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 0           16559      1-May-22           RT1                   25      30.0
# 1           16559      2-May-22           RT1                   20      30.0
# 2           16559      3-May-22           RT1                   17      30.0
# 3           16559      4-May-22           RT1                   21      30.0
# 4           16559      5-May-22           RT1                   16      30.0
# ...           ...           ...           ...                  ...       ...
# 9195        18560     27-Jul-22           RT4                    6      15.0
# 9196        18560     28-Jul-22           RT4                    9      15.0
# 9197        18560     29-Jul-22           RT4                    8      15.0
# 9198        18560     30-Jul-22           RT4                    9      15.0
# 9199        18560     31-Jul-22           RT4                   12      15.0
#
# ...

# %%
Facts_aggregated_bookings.groupby("city")["occupancy_percentage"].mean()
# Out:
# city
# Bangalore    56.594061
# Delhi        61.606265
# Hyderabad    58.144464
# Mumbai       57.936449
# Name: occupancy_percentage, dtype: float64

# %%
Facts_aggregated_bookings.groupby("city")["occupancy_percentage"].mean().plot(kind="bar")
# Out:
# <Axes: xlabel='city'>

# %%
dim_date
# Out:
#          date  mmm yy week no  day_type
# 0   01-May-22  May 22    W 19   weekend
# 1   02-May-22  May 22    W 19  weekeday
# 2   03-May-22  May 22    W 19  weekeday
# 3   04-May-22  May 22    W 19  weekeday
# 4   05-May-22  May 22    W 19  weekeday
# ..        ...     ...     ...       ...
# 87  27-Jul-22  Jul 22    W 31  weekeday
# 88  28-Jul-22  Jul 22    W 31  weekeday
# 89  29-Jul-22  Jul 22    W 31  weekeday
# 90  30-Jul-22  Jul 22    W 31   weekend
# 91  31-Jul-22  Jul 22    W 32   weekend
#
# [92 rows x 4 columns]

# %%
Facts_aggregated_bookings=pd.merge(Facts_aggregated_bookings,dim_date,left_on="check_in_date",right_on="date")
Facts_aggregated_bookings
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 0           16559     10-May-22           RT1                   18      30.0
# 1           16559     10-May-22           RT2                   25      41.0
# 2           16559     10-May-22           RT3                   20      32.0
# 3           16559     10-May-22           RT4                   13      18.0
# 4           19562     10-May-22           RT1                   18      30.0
# ...           ...           ...           ...                  ...       ...
# 6495        17564     31-Jul-22           RT4                   10      17.0
# 6496        18560     31-Jul-22           RT1                   22      30.0
# 6497        18560     31-Jul-22           RT2                   34      40.0
# 6498        18560     31-Jul-22           RT3                   17      24.0
# 6499        18560     31-Jul-22           RT4                   12      15.0
#
# ...

# %%
Facts_aggregated_bookings.groupby("day_type")["occupancy_percentage"].mean().round(2)
# Out:
# day_type
# weekeday    50.90
# weekend     72.39
# Name: occupancy_percentage, dtype: float64

# %%
Facts_aggregated_bookings
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 0           16559     10-May-22           RT1                   18      30.0
# 1           16559     10-May-22           RT2                   25      41.0
# 2           16559     10-May-22           RT3                   20      32.0
# 3           16559     10-May-22           RT4                   13      18.0
# 4           19562     10-May-22           RT1                   18      30.0
# ...           ...           ...           ...                  ...       ...
# 6495        17564     31-Jul-22           RT4                   10      17.0
# 6496        18560     31-Jul-22           RT1                   22      30.0
# 6497        18560     31-Jul-22           RT2                   34      40.0
# 6498        18560     31-Jul-22           RT3                   17      24.0
# 6499        18560     31-Jul-22           RT4                   12      15.0
#
# ...

# %%
Facts_aggregated_bookings["mmm yy"].unique()
# Out:
# array(['May 22', 'Jun 22', 'Jul 22'], dtype=object)

# %%
Facts_aggregated_bookings_June=Facts_aggregated_bookings[Facts_aggregated_bookings["mmm yy"]=="Jun 22"]
Facts_aggregated_bookings_June
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 2200        16559     10-Jun-22           RT1                   20      30.0
# 2201        16559     10-Jun-22           RT2                   26      41.0
# 2202        16559     10-Jun-22           RT3                   20      32.0
# 2203        16559     10-Jun-22           RT4                   11      18.0
# 2204        19562     10-Jun-22           RT1                   19      30.0
# ...           ...           ...           ...                  ...       ...
# 4295        17564     30-Jun-22           RT4                    7      17.0
# 4296        18560     30-Jun-22           RT1                   18      30.0
# 4297        18560     30-Jun-22           RT2                   24      40.0
# 4298        18560     30-Jun-22           RT3                   14      24.0
# 4299        18560     30-Jun-22           RT4                    8      15.0
#
# ...

# %%
Facts_aggregated_bookings_June.groupby("city")["occupancy_percentage"].mean()
# Out:
# city
# Bangalore    56.578449
# Delhi        62.474136
# Hyderabad    58.457791
# Mumbai       58.382632
# Name: occupancy_percentage, dtype: float64

# %%
Facts_aggregated_bookings_July=Facts_aggregated_bookings[Facts_aggregated_bookings["mmm yy"]=="Jul 22"]
Facts_aggregated_bookings_July
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 4300        16559     10-Jul-22           RT1                   26      30.0
# 4301        16559     10-Jul-22           RT2                   38      41.0
# 4302        16559     10-Jul-22           RT3                   28      32.0
# 4303        16559     10-Jul-22           RT4                   17      18.0
# 4304        19562     10-Jul-22           RT1                   26      30.0
# ...           ...           ...           ...                  ...       ...
# 6495        17564     31-Jul-22           RT4                   10      17.0
# 6496        18560     31-Jul-22           RT1                   22      30.0
# 6497        18560     31-Jul-22           RT2                   34      40.0
# 6498        18560     31-Jul-22           RT3                   17      24.0
# 6499        18560     31-Jul-22           RT4                   12      15.0
#
# ...

# %%
Facts_aggregated_bookings_July.groupby("city")["occupancy_percentage"].mean()
# Out:
# city
# Bangalore    54.073812
# Delhi        59.177655
# Hyderabad    55.357877
# Mumbai       55.235719
# Name: occupancy_percentage, dtype: float64

# %%
Facts_aggregated_bookings_May=Facts_aggregated_bookings[Facts_aggregated_bookings["mmm yy"]=="May 22"]
Facts_aggregated_bookings_May
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 0           16559     10-May-22           RT1                   18      30.0
# 1           16559     10-May-22           RT2                   25      41.0
# 2           16559     10-May-22           RT3                   20      32.0
# 3           16559     10-May-22           RT4                   13      18.0
# 4           19562     10-May-22           RT1                   18      30.0
# ...           ...           ...           ...                  ...       ...
# 2195        17564     31-May-22           RT4                    6      17.0
# 2196        18560     31-May-22           RT1                   12      30.0
# 2197        18560     31-May-22           RT2                   18      40.0
# 2198        18560     31-May-22           RT3                   14      24.0
# 2199        18560     31-May-22           RT4                    9      15.0
#
# ...

# %%
Facts_aggregated_bookings_May.groupby("city")["occupancy_percentage"].mean()
# Out:
# city
# Bangalore    55.275325
# Delhi        59.650308
# Hyderabad    57.062255
# Mumbai       56.803194
# Name: occupancy_percentage, dtype: float64

# %%
new_data_august=pd.read_csv("/content/new_data_august.csv")
new_data_august.head()
# Out:
#    property_id  property_name  category       city room_category room_class  \
# 0        16559  Atliq Exotica    Luxury     Mumbai           RT1   Standard
# 1        19562      Atliq Bay    Luxury  Bangalore           RT1   Standard
# 2        19563   Atliq Palace  Business  Bangalore           RT1   Standard
# 3        19558   Atliq Grands    Luxury  Bangalore           RT1   Standard
# 4        19560     Atliq City  Business  Bangalore           RT1   Standard
#
#   check_in_date  mmm yy week no  day_type  successful_bookings  capacity  \
# 0     01-Aug-22  Aug-22    W 32  weekeday                   30        30
# 1     01-Aug-22  Aug-22    W 32  weekeday                   21        30
# 2     01-Aug-22  Aug-22    W 32  weekeday                   23        30
# 3     01-Aug-22  Aug-22    W 32  weekeday                   30        40
# 4     01-Aug-22  Aug-22    W 32  weekeday                   20        26
#
#      occ%
# 0  100.00
# 1   70.00
# 2   76.67
# 3   75.00
# 4   76.92

# %%
Facts_aggregated_bookings=pd.concat([Facts_aggregated_bookings,new_data_august],ignore_index=True,axis=0)

Facts_aggregated_bookings.tail(10)
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 6497        18560     31-Jul-22           RT2                   34      40.0
# 6498        18560     31-Jul-22           RT3                   17      24.0
# 6499        18560     31-Jul-22           RT4                   12      15.0
# 6500        16559     01-Aug-22           RT1                   30      30.0
# 6501        19562     01-Aug-22           RT1                   21      30.0
# 6502        19563     01-Aug-22           RT1                   23      30.0
# 6503        19558     01-Aug-22           RT1                   30      40.0
# 6504        19560     01-Aug-22           RT1                   20      26.0
# 6505        17561     01-Aug-22           RT1                   18      26.0
# 6506        17564     01-Aug-22           RT1                   10      16.0
#
#       occupancy_percentage    room_class  property_name  category       city  \
# ...

# %%
Fact_bookings
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 1        May012216558RT12        16558     30-04-22      1/5/2022
# 4        May012216558RT15        16558     27-04-22      1/5/2022
# 5        May012216558RT16        16558     1/5/2022      1/5/2022
# 6        May012216558RT17        16558     28-04-22      1/5/2022
# 7        May012216558RT18        16558     26-04-22      1/5/2022
# ...                   ...          ...          ...           ...
# 134584   Jul312217564RT45        17564     30-07-22      31-07-22
# 134585   Jul312217564RT46        17564     29-07-22      31-07-22
# 134587   Jul312217564RT48        17564     30-07-22      31-07-22
# 134588   Jul312217564RT49        17564     29-07-22      31-07-22
# 134589  Jul312217564RT410        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 1           2/5/2022        2.0           RT1           others            NaN
# ...

# %%
Fact_bookings=pd.read_csv("/content/fact_bookings.csv")
Fact_bookings
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 0        May012216558RT11        16558     27-04-22      1/5/2022
# 1        May012216558RT12        16558     30-04-22      1/5/2022
# 2        May012216558RT13        16558     28-04-22      1/5/2022
# 3        May012216558RT14        16558     28-04-22      1/5/2022
# 4        May012216558RT15        16558     27-04-22      1/5/2022
# ...                   ...          ...          ...           ...
# 134585   Jul312217564RT46        17564     29-07-22      31-07-22
# 134586   Jul312217564RT47        17564     30-07-22      31-07-22
# 134587   Jul312217564RT48        17564     30-07-22      31-07-22
# 134588   Jul312217564RT49        17564     29-07-22      31-07-22
# 134589  Jul312217564RT410        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 0           2/5/2022       -3.0           RT1    direct online            1.0
# ...

# %%
Fact_bookings=pd.merge(Fact_bookings,dim_hotels,on="property_id")
Fact_bookings
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 0        May012216558RT11        16558     27-04-22      1/5/2022
# 1        May012216558RT12        16558     30-04-22      1/5/2022
# 2        May012216558RT13        16558     28-04-22      1/5/2022
# 3        May012216558RT14        16558     28-04-22      1/5/2022
# 4        May012216558RT15        16558     27-04-22      1/5/2022
# ...                   ...          ...          ...           ...
# 134585   Jul312217564RT46        17564     29-07-22      31-07-22
# 134586   Jul312217564RT47        17564     30-07-22      31-07-22
# 134587   Jul312217564RT48        17564     30-07-22      31-07-22
# 134588   Jul312217564RT49        17564     29-07-22      31-07-22
# 134589  Jul312217564RT410        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 0           2/5/2022       -3.0           RT1    direct online            1.0
# ...

# %%
Fact_bookings.groupby("city")["revenue_realized"].sum()
# Out:
# city
# Bangalore    420397050
# Delhi        294500318
# Hyderabad    325232870
# Mumbai       668640991
# Name: revenue_realized, dtype: int64

# %%
dim_date
# Out:
#          date  mmm yy week no  day_type
# 0   01-May-22  May 22    W 19   weekend
# 1   02-May-22  May 22    W 19  weekeday
# 2   03-May-22  May 22    W 19  weekeday
# 3   04-May-22  May 22    W 19  weekeday
# 4   05-May-22  May 22    W 19  weekeday
# ..        ...     ...     ...       ...
# 87  27-Jul-22  Jul 22    W 31  weekeday
# 88  28-Jul-22  Jul 22    W 31  weekeday
# 89  29-Jul-22  Jul 22    W 31  weekeday
# 90  30-Jul-22  Jul 22    W 31   weekend
# 91  31-Jul-22  Jul 22    W 32   weekend
#
# [92 rows x 4 columns]

# %%
pd.merge(Fact_bookings,dim_date,left_on="check_in_date",right_on="date")
# Out:
# Empty DataFrame
# Columns: [booking_id, property_id, booking_date, check_in_date, checkout_date, no_guests, room_category, booking_platform, ratings_given, booking_status, revenue_generated, revenue_realized, property_name, category, city, date, mmm yy, week no, day_type]
# Index: []

# %%
pd.to_datetime(dim_date["date"])
# Out:
# 0    2022-05-01
# 1    2022-05-02
# 2    2022-05-03
# 3    2022-05-04
# 4    2022-05-05
#         ...
# 87   2022-07-27
# 88   2022-07-28
# 89   2022-07-29
# 90   2022-07-30
# 91   2022-07-31
# Name: date, Length: 92, dtype: datetime64[ns]

# %%
dim_date["date"]=pd.to_datetime(dim_date["date"])
dim_date
# Out:
#          date  mmm yy week no  day_type
# 0  2022-05-01  May 22    W 19   weekend
# 1  2022-05-02  May 22    W 19  weekeday
# 2  2022-05-03  May 22    W 19  weekeday
# 3  2022-05-04  May 22    W 19  weekeday
# 4  2022-05-05  May 22    W 19  weekeday
# ..        ...     ...     ...       ...
# 87 2022-07-27  Jul 22    W 31  weekeday
# 88 2022-07-28  Jul 22    W 31  weekeday
# 89 2022-07-29  Jul 22    W 31  weekeday
# 90 2022-07-30  Jul 22    W 31   weekend
# 91 2022-07-31  Jul 22    W 32   weekend
#
# [92 rows x 4 columns]

# %%
pd.to_datetime(Fact_bookings["check_in_date"])
# Out:
# 0        2022-01-05
# 1        2022-01-05
# 2        2022-01-05
# 3        2022-01-05
# 4        2022-01-05
#             ...
# 134585   2022-07-31
# 134586   2022-07-31
# 134587   2022-07-31
# 134588   2022-07-31
# 134589   2022-07-31
# Name: check_in_date, Length: 134590, dtype: datetime64[ns]

# %%
Fact_bookings["check_in_date"]=pd.to_datetime(Fact_bookings["check_in_date"])
Fact_bookings
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 0        May012216558RT11        16558     27-04-22    2022-01-05
# 1        May012216558RT12        16558     30-04-22    2022-01-05
# 2        May012216558RT13        16558     28-04-22    2022-01-05
# 3        May012216558RT14        16558     28-04-22    2022-01-05
# 4        May012216558RT15        16558     27-04-22    2022-01-05
# ...                   ...          ...          ...           ...
# 134585   Jul312217564RT46        17564     29-07-22    2022-07-31
# 134586   Jul312217564RT47        17564     30-07-22    2022-07-31
# 134587   Jul312217564RT48        17564     30-07-22    2022-07-31
# 134588   Jul312217564RT49        17564     29-07-22    2022-07-31
# 134589  Jul312217564RT410        17564     31-07-22    2022-07-31
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 0           2/5/2022       -3.0           RT1    direct online            1.0
# ...

# %%
Facts_aggregated_bookings
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 0           16559     10-May-22           RT1                   18      30.0
# 1           16559     10-May-22           RT2                   25      41.0
# 2           16559     10-May-22           RT3                   20      32.0
# 3           16559     10-May-22           RT4                   13      18.0
# 4           19562     10-May-22           RT1                   18      30.0
# ...           ...           ...           ...                  ...       ...
# 6502        19563     01-Aug-22           RT1                   23      30.0
# 6503        19558     01-Aug-22           RT1                   30      40.0
# 6504        19560     01-Aug-22           RT1                   20      26.0
# 6505        17561     01-Aug-22           RT1                   18      26.0
# 6506        17564     01-Aug-22           RT1                   10      16.0
#
# ...

# %%
pd.to_datetime(Facts_aggregated_bookings["check_in_date"])
# Out:
# 0      2022-05-10
# 1      2022-05-10
# 2      2022-05-10
# 3      2022-05-10
# 4      2022-05-10
#           ...
# 6502   2022-08-01
# 6503   2022-08-01
# 6504   2022-08-01
# 6505   2022-08-01
# 6506   2022-08-01
# Name: check_in_date, Length: 6507, dtype: datetime64[ns]

# %%
Fact_bookings.groupby("city")["revenue_realized"].sum()
# Out:
# city
# Bangalore    420397050
# Delhi        294500318
# Hyderabad    325232870
# Mumbai       668640991
# Name: revenue_realized, dtype: int64

# %%
Fact_bookings=pd.read_csv("/content/fact_bookings.csv")
Fact_bookings
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 0        May012216558RT11        16558     27-04-22      1/5/2022
# 1        May012216558RT12        16558     30-04-22      1/5/2022
# 2        May012216558RT13        16558     28-04-22      1/5/2022
# 3        May012216558RT14        16558     28-04-22      1/5/2022
# 4        May012216558RT15        16558     27-04-22      1/5/2022
# ...                   ...          ...          ...           ...
# 134585   Jul312217564RT46        17564     29-07-22      31-07-22
# 134586   Jul312217564RT47        17564     30-07-22      31-07-22
# 134587   Jul312217564RT48        17564     30-07-22      31-07-22
# 134588   Jul312217564RT49        17564     29-07-22      31-07-22
# 134589  Jul312217564RT410        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 0           2/5/2022       -3.0           RT1    direct online            1.0
# ...

# %%
Fact_bookings=Fact_bookings[Fact_bookings["no_guests"]>0]
Fact_bookings
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 1        May012216558RT12        16558     30-04-22      1/5/2022
# 2        May012216558RT13        16558     28-04-22      1/5/2022
# 4        May012216558RT15        16558     27-04-22      1/5/2022
# 5        May012216558RT16        16558     1/5/2022      1/5/2022
# 6        May012216558RT17        16558     28-04-22      1/5/2022
# ...                   ...          ...          ...           ...
# 134584   Jul312217564RT45        17564     30-07-22      31-07-22
# 134585   Jul312217564RT46        17564     29-07-22      31-07-22
# 134587   Jul312217564RT48        17564     30-07-22      31-07-22
# 134588   Jul312217564RT49        17564     29-07-22      31-07-22
# 134589  Jul312217564RT410        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 1           2/5/2022        2.0           RT1           others            NaN
# ...

# %%
dim_hotels
# Out:
#     property_id  property_name  category       city
# 0         16558   Atliq Grands    Luxury      Delhi
# 1         16559  Atliq Exotica    Luxury     Mumbai
# 2         16560     Atliq City  Business      Delhi
# 3         16561      Atliq Blu    Luxury      Delhi
# 4         16562      Atliq Bay    Luxury      Delhi
# 5         16563   Atliq Palace  Business      Delhi
# 6         17558   Atliq Grands    Luxury     Mumbai
# 7         17559  Atliq Exotica    Luxury     Mumbai
# 8         17560     Atliq City  Business     Mumbai
# 9         17561      Atliq Blu    Luxury     Mumbai
# 10        17562      Atliq Bay    Luxury     Mumbai
# 11        17563   Atliq Palace  Business     Mumbai
# 12        18558   Atliq Grands    Luxury  Hyderabad
# 13        18559  Atliq Exotica    Luxury  Hyderabad
# 14        18560     Atliq City  Business  Hyderabad
# 15        18561      Atliq Blu    Luxury  Hyderabad
# 16        18562      Atliq Bay    Luxury  Hyderabad
# ...

# %%
Final_bookings=pd.merge(Fact_bookings,dim_hotels,on="property_id")

# %%
Final_bookings
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 0        May012216558RT12        16558     30-04-22      1/5/2022
# 1        May012216558RT13        16558     28-04-22      1/5/2022
# 2        May012216558RT15        16558     27-04-22      1/5/2022
# 3        May012216558RT16        16558     1/5/2022      1/5/2022
# 4        May012216558RT17        16558     28-04-22      1/5/2022
# ...                   ...          ...          ...           ...
# 134573   Jul312217564RT45        17564     30-07-22      31-07-22
# 134574   Jul312217564RT46        17564     29-07-22      31-07-22
# 134575   Jul312217564RT48        17564     30-07-22      31-07-22
# 134576   Jul312217564RT49        17564     29-07-22      31-07-22
# 134577  Jul312217564RT410        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 0           2/5/2022        2.0           RT1           others            NaN
# ...

# %%
Final_bookings.groupby("category")["revenue_realized"].sum()
# Out:
# category
# Business     655967037
# Luxury      1052636842
# Name: revenue_realized, dtype: int64

# %%
Final_bookings.groupby("city")["ratings_given"].mean()
# Out:
# city
# Bangalore    3.407681
# Delhi        3.779265
# Hyderabad    3.661041
# Mumbai       3.650545
# Name: ratings_given, dtype: float64

# %%
Final_bookings.groupby("booking_platform")["revenue_realized"].sum().plot(kind="pie")
# Out:
# <Axes: ylabel='revenue_realized'>
